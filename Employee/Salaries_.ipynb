# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kaggle/sf-salaries")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 11.5M/11.5M [00:00<00:00, 201MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kaggle/sf-salaries/versions/5

# %%
import os
print(os.listdir(path))
# Out:
# ['database.sqlite', 'Salaries.csv']

# %%
import pandas as pd

df = pd.read_csv(path + "/Salaries.csv")
# Out:
# /tmp/ipython-input-2920445262.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + "/Salaries.csv")

# %% [markdown]
# display top 10 rows of the dataset

# %%
df=pd.DataFrame(df)
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# display last 10 rows of the dataset

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# find shape of our dataset

# %%
df.shape
# Out:
# (148654, 13)

# %%
print("Number of row",df.shape[0])
print("Number of column",df.shape[1])
# Out:
# Number of row 148654
# Number of column 13

# %% [markdown]
# getting information about our dataset like total number rows, Total number of column , datatype of each column and memory requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# check null values in the dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# drop id ,Notes,Agency and Status Columns

# %%
df.drop(columns=['Id','Notes','Agency','Status'])
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# set overall statistics about the dataframe

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %% [markdown]
# find occurence of the employee names

# %%
df['EmployeeName'].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# William Wong    11
# Richard Lee     11
# Steven Lee      11
# John Chan        9
# Name: count, dtype: int64

# %% [markdown]
# find the number of unique job titles

# %%
len(df['JobTitle'].value_counts())
# Out:
# 2159

# %% [markdown]
# total number of jobs titles contain captain

# %%
len(df[df['JobTitle'].str.contains('Captain',case=False)])
# Out:
# 552

# %% [markdown]
# total number of job titles contain captain

# %%
len(df[df['JobTitle'].str.contains('CAPTAIN',case=False)])
# Out:
# 552

# %% [markdown]
# display all the Employee names from fire department

# %%
df[df['JobTitle'].str.contains('Fire',case=False)]["EmployeeName"]
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %% [markdown]
# find the  minimum,maximum and average basepay

# %%
df['BasePay'].describe()
# Out:
# count     148049.0
# unique    109900.0
# top            0.0
# freq         875.0
# Name: BasePay, dtype: float64

# %% [markdown]
# replace "Not Provided" in Emoloyeename column to nan

# %%
import numpy as np
df['EmployeeName'].replace("Not provided",np.nan)
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %% [markdown]
# drop the rows having 5 missing values

# %%
df[df.isnull().sum(axis=1)==5]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
df.drop(df[df.isnull().sum(axis=1)==5].index,axis=1)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df[df['EmployeeName'].str.contains('ALBERT PARDINI')]['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# how much albert pardini make (include benefits)

# %%
df.head(1)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %%
df[df['EmployeeName'].str.contains('ALBERT PARDINI')]['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# display name of the person having the highest basepay

# %%
df['BasePay'].max()==df['BasePay']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-397905088.py in <cell line: 0>()
# ----> 1 df['BasePay'].max()==df['BasePay']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in max(self, axis, skipna, numeric_only, **kwargs)
#    6515         **kwargs,
#    6516     ):
# -> 6517         return NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#    6518
#    6519     @doc(make_doc("sum", ndim=1))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in max(self, axis, skipna, numeric_only, **kwargs)
#   12402         **kwargs,
#   12403     ):
# > 12404         return self._stat_function(
#   12405             "max",
#   12406             nanops.nanmax,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
# ...

# %% [markdown]
# find average basepay of all employee per year

# %%
df['BasePay'].replace("Not Provided",np.nan)
df['BasePay']=pd.to_numeric(df['BasePay'],errors='coerce')
print(df['BasePay'].sum())
# Out:
# 9819151073.590002

# %% [markdown]
# find average pasepay of all employee per jobtitle

# %%
avg_basepay = df.groupby("JobTitle")["BasePay"].mean()
print(avg_basepay)
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %% [markdown]
# find the average basepay of employee having job title ACCOUNTANT

# %%
df[df['JobTitle']=='ACCOUNTANT']['BasePay'].mean()
# df[df['JobTitle'].str.contains('ACCOUNTANT',case=False)]['BasePay'].mean()
# Out:
# np.float64(46643.172)

# %% [markdown]
# find top 5 most common jobs

# %%
df['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64
