# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("utkarsharya/ecommerce-purchases")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 984k/984k [00:00<00:00, 90.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/utkarsharya/ecommerce-purchases/versions/1

# %%
import os
print(os.listdir(path))
# Out:
# ['Ecommerce Purchases']

# %%
import pandas as pd

dataset = pd.read_csv(path + "/Ecommerce Purchases")
print(dataset.head())
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# DISPLAY TOP 10 ROWS OF THE DATASET

# %%
dataset.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# check last 10 row of the dataset

# %%
dataset.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# check datatype of each column

# %%
dataset.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# check null values in the dataset

# %%
dataset.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# how many rows and columns are there in our dataset

# %%
data=dataset.shape

# %%
print("number of row :",dataset.shape[0])
# Out:
# number of row : 10000

# %%
print("number of column :",dataset.shape[1])
# Out:
# number of column : 14

# %% [markdown]
# highest and lowest purchased prices

# %%
dataset['Purchase Price'].max()
# Out:
# 99.99

# %%
dataset['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# Average purchase price

# %%
dataset['Purchase Price'].mean()
# Out:
# np.float64(50.347302)

# %% [markdown]
# how many people have french "fr as their language "

# %%
len(dataset[dataset['Language'].str.contains('fr')])
# Out:
# 1097

# %% [markdown]
# job title contain engineer

# %%
len(dataset[dataset['Job'].str.contains('Engineer',case=False)])
# Out:
# 984

# %% [markdown]
# find email of the person with the follong ip address 132,207,160,22

# %%
dataset['Email'][dataset['IP Address'].str.contains('132.207.160.22')]
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# how many people have mastercard as their chrditr card card provider and mnade a purchase above 50?

# %%
dataset.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
len(dataset[(dataset['CC Provider'].str.contains('Mastercard') )& (dataset['Purchase Price']>=50)])
# Out:
# 405

# %% [markdown]
# find email of the person with the following credit card number 4664825258997302

# %%
dataset['Email'][dataset['Credit Card']==4664825258997302]
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %% [markdown]
# how many people purchase during the am nd how many people purchase during pm

# %%
len(dataset['AM or PM']=='AM')
# Out:
# 10000

# %%
len(dataset['AM or PM'].str.contains('PM',case=False))
# Out:
# 10000

# %%
dataset['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# how many people have a credit card that expires in 2020 ?

# %%
def fun():
  count=0
  for date in dataset['CC Exp Date']:
    if date.split('/')[1]=='20':
      count=count+1
  return count

# %%
fun()
# Out:
# 988

# %%
dataset[dataset['CC Exp Date'].apply(lambda x:x[3:]=='20')]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  80 Fq       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# ...                                                 ...    ...      ...
# 9883        751 Petersen Groves\nLake Rebecca, NM 55875  61 tE       PM
# 9901      908 Norman Burgs\nPhillipsberg, VT 92023-9956  90 Ng       PM
# 9911  44320 Gray Centers Suite 325\nJenniferfurt, OK...  19 Bf       PM
# 9957             73556 Chase Pine\nBrucemouth, MP 73473  25 rU       PM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# top 5 most popular email providers

# %%
dataset['Email'].apply(lambda x:x.split('@')[1]).value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
